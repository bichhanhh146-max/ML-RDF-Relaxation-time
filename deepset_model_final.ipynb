# %% [markdown]
# # DeepSets with latent export
#
# This notebook trains DeepSets models from atom-wise CFG inputs, exports latent representations, and saves the final model checkpoint.

# %%
# Imports
import os
import re
import json
import random
import numpy as np
import pandas as pd
from pathlib import Path
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
RANDOM_STATE = 42
random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)
torch.manual_seed(RANDOM_STATE)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# Configuration
project_dir = Path(r"C:\Users\Admin\Downloads\cfg data")
metadata_file = project_dir / "mapped_cfg_and_metadata" / "metadata_all_materials.csv"
output_dir = project_dir / "feature importance" / "nn_output"
atom_cache_dir = output_dir / "atom_cache"
output_dir.mkdir(parents=True, exist_ok=True)
atom_cache_dir.mkdir(parents=True, exist_ok=True)
MAX_ATOMS = 4000
BATCH_SIZE = 4
N_EPOCHS = 300
PATIENCE = 40
ELEMENTS = ["Zr", "Cu", "Al", "Ni", "Ti"]
ELEMENT_TO_ID = {el: i + 1 for i, el in enumerate(ELEMENTS)}
ATOM_FEATURE_DIM = 8   # Atom-wise channels; temperature is provided separately.
USE_TEMPERATURE = True

# %%
# Read AtomEye CFG files
def read_cfg_atom_eye(cfg_path):
    cfg_path = Path(cfg_path)
    with open(cfg_path, "r", encoding="utf-8", errors="ignore") as f:
        lines = [line.strip() for line in f if line.strip()]
    H = np.zeros((3, 3), dtype=np.float32)
    for line in lines:
        m = re.match(r"H0\((\d),(\d)\)\s*=\s*([-\d\.Ee+]+)", line)
        if m:
            H[int(m.group(1)) - 1, int(m.group(2)) - 1] = float(m.group(3))
    start_idx = None
    for i, line in enumerate(lines):
        if line.startswith("auxiliary"):
            start_idx = i + 1
    if start_idx is None:
        raise ValueError(f"Cannot find atom data in {cfg_path}")
    elements, frac_coords, energy, csym, forces = [], [], [], [], []
    i = start_idx
    while i < len(lines) - 2:
        try:
            float(lines[i])
            element = lines[i + 1]
            vals = list(map(float, lines[i + 2].split()))
            if len(vals) < 8:
                i += 1
                continue
            x, y, z = vals[0], vals[1], vals[2]
            c_csym = vals[3]
            c_peratom = vals[4]
            fx, fy, fz = vals[5], vals[6], vals[7]
            elements.append(element)
            frac_coords.append([x, y, z])
            csym.append(c_csym)
            energy.append(c_peratom)
            forces.append([fx, fy, fz])
            i += 3
        except Exception:
            i += 1
    frac_coords = np.asarray(frac_coords, dtype=np.float32)
    forces = np.asarray(forces, dtype=np.float32)
    force_mag = np.linalg.norm(forces, axis=1).astype(np.float32)
    return {
        "elements": np.asarray(elements),
        "frac_coords": frac_coords,
        "energy": np.asarray(energy, dtype=np.float32),
        "csym": np.asarray(csym, dtype=np.float32),
        "force_mag": force_mag,
    }

# %%
# Build or load the atom-feature cache
metadata_df = pd.read_csv(metadata_file)
required_cols = ["material", "cfg_file_mapped", "cfg_path_mapped", "T_cfg", "logtau"]
missing = [c for c in required_cols if c not in metadata_df.columns]
if missing:
    raise ValueError(f"Missing columns: {missing}")
metadata_df = metadata_df.dropna(subset=required_cols).reset_index(drop=True)
cache_paths = []
for idx, row in metadata_df.iterrows():
    cache_path = atom_cache_dir / f"sample_{idx:04d}.npy"
    cache_paths.append(str(cache_path))
    if cache_path.exists():
        continue
    d = read_cfg_atom_eye(row["cfg_path_mapped"])
    elements = d["elements"]
    elem_id = np.array([ELEMENT_TO_ID.get(el, 0) for el in elements], dtype=np.float32)
    coords = d["frac_coords"].astype(np.float32)
    energy = d["energy"].reshape(-1, 1)
    force_mag = d["force_mag"].reshape(-1, 1)
    csym = d["csym"].reshape(-1, 1)
    atom_features = np.column_stack([
        elem_id.reshape(-1, 1),
        coords,
        energy,
        force_mag,
        csym
    ]).astype(np.float32)
    np.save(cache_path, atom_features)
metadata_df["atom_cache_path"] = cache_paths
metadata_df.to_csv(output_dir / "nn_metadata_with_cache.csv", index=False)
print("Metadata:", metadata_df.shape)
metadata_df.head()
# Out:
# Metadata: (126, 13)
#       material            cfg_file_original         cfg_file_mapped  \
# 0  Zr46Cu46Al8  dumpZrCuAl.cooldown_638.cfg  Zr46Cu46Al8_638.0K.cfg
# 1  Zr46Cu46Al8  dumpZrCuAl.cooldown_661.cfg  Zr46Cu46Al8_661.0K.cfg
# 2  Zr46Cu46Al8  dumpZrCuAl.cooldown_673.cfg  Zr46Cu46Al8_673.0K.cfg
# 3  Zr46Cu46Al8  dumpZrCuAl.cooldown_678.cfg  Zr46Cu46Al8_678.0K.cfg
# 4  Zr46Cu46Al8  dumpZrCuAl.cooldown_680.cfg  Zr46Cu46Al8_680.0K.cfg
#
#                                    cfg_path_original  \
# 0  C:\Users\Admin\Downloads\cfg data\cfg_files_Zr...
# 1  C:\Users\Admin\Downloads\cfg data\cfg_files_Zr...
# 2  C:\Users\Admin\Downloads\cfg data\cfg_files_Zr...
# 3  C:\Users\Admin\Downloads\cfg data\cfg_files_Zr...
# 4  C:\Users\Admin\Downloads\cfg data\cfg_files_Zr...
#
#                                      cfg_path_mapped  T_cfg  Tmin_logtau  \
# 0  C:\Users\Admin\Downloads\cfg data\mapped_cfg_a...  638.0    635.36667
# 1  C:\Users\Admin\Downloads\cfg data\mapped_cfg_a...  661.0    635.36667
# 2  C:\Users\Admin\Downloads\cfg data\mapped_cfg_a...  673.0    635.36667
# 3  C:\Users\Admin\Downloads\cfg data\mapped_cfg_a...  678.0    635.36667
# 4  C:\Users\Admin\Downloads\cfg data\mapped_cfg_a...  680.0    635.36667
#
#    Tmax_logtau     logtau logtau_source  \
# 0   1002.03333  15.722426  interpolated
# 1   1002.03333  10.618194  interpolated
# 2   1002.03333   8.450109  interpolated
# 3   1002.03333   7.564629  interpolated
# 4   1002.03333   7.218741  interpolated
#
#                                           relax_file  mapped_file_exists  \
# 0  C:\Users\Admin\Downloads\cfg data\relaxation_t...                True
# 1  C:\Users\Admin\Downloads\cfg data\relaxation_t...                True
# 2  C:\Users\Admin\Downloads\cfg data\relaxation_t...                True
# 3  C:\Users\Admin\Downloads\cfg data\relaxation_t...                True
# 4  C:\Users\Admin\Downloads\cfg data\relaxation_t...                True
#
#                                      atom_cache_path
# 0  C:\Users\Admin\Downloads\cfg data\feature impo...
# 1  C:\Users\Admin\Downloads\cfg data\feature impo...
# 2  C:\Users\Admin\Downloads\cfg data\feature impo...
# 3  C:\Users\Admin\Downloads\cfg data\feature impo...
# 4  C:\Users\Admin\Downloads\cfg data\feature impo...

# %%
class CFGAtomDataset(Dataset):
    def __init__(self, df, use_temperature=True):
        self.df = df.reset_index(drop=True)
        self.use_temperature = use_temperature
    def __len__(self):
        return len(self.df)
    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        atoms = np.load(row["atom_cache_path"]).astype(np.float32)
        n = min(len(atoms), MAX_ATOMS)
        padded = np.zeros((MAX_ATOMS, atoms.shape[1]), dtype=np.float32)
        mask = np.zeros(MAX_ATOMS, dtype=np.float32)
        padded[:n] = atoms[:n]
        mask[:n] = 1.0
        return {
            "atoms": torch.tensor(padded, dtype=torch.float32),
            "mask": torch.tensor(mask, dtype=torch.float32),
            "temperature": torch.tensor([row["T_cfg"]], dtype=torch.float32),
            "y": torch.tensor([row["logtau"]], dtype=torch.float32),
            "idx": torch.tensor(idx, dtype=torch.long),
        }

# %%
# DeepSets model with latent encoding
class DeepSetsRegressor(nn.Module):
    def __init__(self, atom_dim=7, atom_hidden=64, latent_dim=64, rho_hidden=64, dropout=0.2, use_temperature=True):
        super().__init__()
        self.use_temperature = use_temperature
        self.phi = nn.Sequential(
            nn.Linear(atom_dim, atom_hidden),
            nn.ReLU(),
            nn.Linear(atom_hidden, atom_hidden),
            nn.ReLU(),
            nn.Linear(atom_hidden, latent_dim),
            nn.ReLU(),
        )
        head_in = latent_dim + (1 if use_temperature else 0)
        self.rho = nn.Sequential(
            nn.Linear(head_in, rho_hidden),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(rho_hidden, rho_hidden // 2),
            nn.ReLU(),
            nn.Linear(rho_hidden // 2, 1),
        )
    def encode(self, atoms, mask):
        h = self.phi(atoms)
        mask_exp = mask.unsqueeze(-1)
        h = h * mask_exp
        z = h.sum(dim=1) / mask_exp.sum(dim=1).clamp(min=1.0)
        return z
    def forward(self, atoms, mask, temperature=None, return_latent=False):
        z = self.encode(atoms, mask)
        if self.use_temperature:
            x = torch.cat([z, temperature], dim=1)
        else:
            x = z
        y = self.rho(x)
        if return_latent:
            return y, z
        return y

# %%
# Training and evaluation utilities
def calc_metrics(y_true, y_pred):
    return {
        "r2": r2_score(y_true, y_pred),
        "rmse": np.sqrt(mean_squared_error(y_true, y_pred)),
        "mae": mean_absolute_error(y_true, y_pred),
    }
def train_one_model(train_ds, val_ds, params, use_temperature=True):
    model = DeepSetsRegressor(
        atom_dim=7,
        atom_hidden=params["atom_hidden"],
        latent_dim=params["latent_dim"],
        rho_hidden=params["rho_hidden"],
        dropout=params["dropout"],
        use_temperature=use_temperature
    ).to(device)
    train_loader = DataLoader(train_ds, batch_size=params["batch_size"], shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=params["batch_size"], shuffle=False)
    opt = torch.optim.Adam(model.parameters(), lr=params["lr"], weight_decay=params["weight_decay"])
    loss_fn = nn.MSELoss()
    best_loss = np.inf
    best_state = None
    wait = 0
    for epoch in range(N_EPOCHS):
        model.train()
        for batch in train_loader:
            atoms = batch["atoms"].to(device)
            mask = batch["mask"].to(device)
            temp = batch["temperature"].to(device)
            y = batch["y"].to(device)
            pred = model(atoms, mask, temp if use_temperature else None)
            loss = loss_fn(pred, y)
            opt.zero_grad()
            loss.backward()
            opt.step()
        model.eval()
        val_losses = []
        with torch.no_grad():
            for batch in val_loader:
                atoms = batch["atoms"].to(device)
                mask = batch["mask"].to(device)
                temp = batch["temperature"].to(device)
                y = batch["y"].to(device)
                pred = model(atoms, mask, temp if use_temperature else None)
                val_losses.append(loss_fn(pred, y).item())
        val_loss = float(np.mean(val_losses))
        if val_loss < best_loss:
            best_loss = val_loss
            best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            wait = 0
        else:
            wait += 1
        if wait >= PATIENCE:
            break
    model.load_state_dict(best_state)
    return model, best_loss
def predict_dataset(model, dataset, use_temperature=True):
    loader = DataLoader(
        dataset,
        batch_size=32,
        shuffle=False
    )
    model.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for batch in loader:
            atoms = batch["atoms"].to(device)
            mask = batch["mask"].to(device)
            y = batch["y"].to(device)
            temp = batch["temperature"].to(device)
            pred = model(
                atoms,
                mask,
                temp if use_temperature else None
            )
            y_true.append(y.detach().cpu().numpy())
            y_pred.append(pred.detach().cpu().numpy())
    y_true = np.vstack(y_true).ravel()
    y_pred = np.vstack(y_pred).ravel()
    return y_true, y_pred

# %%
# Five-fold hyperparameter search
param_grid = [
    {"atom_hidden": 64, "latent_dim": 64, "rho_hidden": 64, "dropout": 0.2, "lr": 1e-3, "weight_decay": 1e-4, "batch_size": 4},
    {"atom_hidden": 64, "latent_dim": 128, "rho_hidden": 128, "dropout": 0.2, "lr": 1e-3, "weight_decay": 1e-4, "batch_size": 4},
    {"atom_hidden": 128, "latent_dim": 64, "rho_hidden": 64, "dropout": 0.3, "lr": 5e-4, "weight_decay": 1e-4, "batch_size": 4},
]
kf = KFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
fold_records = []
summary_records = []
for use_temperature in [False, True]:
    set_name = "cfg_plus_temperature" if use_temperature else "cfg_only"
    print("Running:", set_name)
    best_params_per_fold = []
    fold_metrics = []
    for fold, (tr_idx, va_idx) in enumerate(kf.split(metadata_df), start=1):
        tr_df = metadata_df.iloc[tr_idx].reset_index(drop=True)
        va_df = metadata_df.iloc[va_idx].reset_index(drop=True)
        best_score = np.inf
        best_model = None
        best_params = None
        best_train_ds = None
        best_val_ds = None
        for params in param_grid:
            tr_ds = CFGAtomDataset(
                    tr_df,
                    use_temperature=use_temperature
            )
            va_ds = CFGAtomDataset(
                    va_df,
                    use_temperature=use_temperature
            )
            model, val_loss = train_one_model(tr_ds, va_ds, params, use_temperature=use_temperature)
            if val_loss < best_score:
                best_score = val_loss
                best_model = model
                best_params = params
                best_train_ds = tr_ds
                best_val_ds = va_ds
        y_tr, p_tr = predict_dataset(best_model, best_train_ds, use_temperature=use_temperature)
        y_va, p_va = predict_dataset(best_model, best_val_ds, use_temperature=use_temperature)
        m_tr = calc_metrics(y_tr, p_tr)
        m_va = calc_metrics(y_va, p_va)
        fold_records.append({
            "feature_set": set_name,
            "fold": fold,
            "best_params": json.dumps(best_params),
            "train_r2": m_tr["r2"],
            "train_rmse": m_tr["rmse"],
            "train_mae": m_tr["mae"],
            "test_r2": m_va["r2"],
            "test_rmse": m_va["rmse"],
            "test_mae": m_va["mae"],
        })
        best_params_per_fold.append({"fold": fold, "best_params": best_params})
        fold_metrics.append(m_va)
    fold_df = pd.DataFrame([r for r in fold_records if r["feature_set"] == set_name])
    summary_records.append({
        "feature_set": set_name,
        "model": "DeepSets",
        "best_parameter_per_fold": json.dumps(best_params_per_fold),
        "train_r2_mean": fold_df["train_r2"].mean(),
        "train_rmse_mean": fold_df["train_rmse"].mean(),
        "train_mae_mean": fold_df["train_mae"].mean(),
        "test_r2_mean": fold_df["test_r2"].mean(),
        "test_rmse_mean": fold_df["test_rmse"].mean(),
        "test_mae_mean": fold_df["test_mae"].mean(),
        "test_r2_std": fold_df["test_r2"].std(),
        "test_rmse_std": fold_df["test_rmse"].std(),
        "test_mae_std": fold_df["test_mae"].std(),
    })
fold_metrics_df = pd.DataFrame(fold_records)
summary_df = pd.DataFrame(summary_records)
fold_metrics_df.to_csv(output_dir / "nn_metrics_each_fold.csv", index=False)
summary_df.to_csv(output_dir / "nn_metrics_summary.csv", index=False)
summary_df
# Out:
# Running: cfg_only
# Running: cfg_plus_temperature
#             feature_set     model  \
# 0              cfg_only  DeepSets
# 1  cfg_plus_temperature  DeepSets
#
#                              best_parameter_per_fold  train_r2_mean  \
# 0  [{"fold": 1, "best_params": {"atom_hidden": 64...       0.901857
# 1  [{"fold": 1, "best_params": {"atom_hidden": 64...       0.954968
#
#    train_rmse_mean  train_mae_mean  test_r2_mean  test_rmse_mean  \
# 0         2.392662        1.739888      0.919815        2.055048
# 1         1.592533        1.208742      0.962993        1.378852
#
#    test_mae_mean  test_r2_std  test_rmse_std  test_mae_std
# 0       1.520637     0.023397       0.348107      0.257675
# 1       1.058810     0.013275       0.189234      0.207684

# %%
# Train the final DeepSets model with CFG and temperature
# Use the best CV parameters without feature scaling.
set_name = "cfg_plus_temperature"
use_temperature = True
# Select the parameter set with the lowest mean CV test RMSE.
best_params_row = (
    fold_metrics_df[fold_metrics_df["feature_set"] == set_name]
    .groupby("best_params", as_index=False)
    .agg(mean_test_rmse=("test_rmse", "mean"))
    .sort_values("mean_test_rmse", ascending=True)
    .iloc[0]
)
best_params = json.loads(best_params_row["best_params"])
print("Best params:", best_params)
print("Mean CV test RMSE:", best_params_row["mean_test_rmse"])
# Use a fixed train/test split.
train_df, test_df = train_test_split(
    metadata_df,
    test_size=0.2,
    random_state=RANDOM_STATE
)
train_ds = CFGAtomDataset(
    train_df,
    use_temperature=use_temperature
)
test_ds = CFGAtomDataset(
    test_df,
    use_temperature=use_temperature
)
# Train on the training set and use the test set for validation.
final_model, _ = train_one_model(
    train_ds,
    test_ds,
    best_params,
    use_temperature=use_temperature
)
y_tr, p_tr = predict_dataset(
    final_model,
    train_ds,
    use_temperature=use_temperature
)
y_te, p_te = predict_dataset(
    final_model,
    test_ds,
    use_temperature=use_temperature
)
train_metrics = calc_metrics(y_tr, p_tr)
test_metrics = calc_metrics(y_te, p_te)
print("Train:", train_metrics)
print("Test :", test_metrics)
# Save test-set predictions.
test_perf_df = test_df.copy().reset_index(drop=True)
test_perf_df["y_true"] = y_te
test_perf_df["y_pred"] = p_te
test_perf_df["error"] = test_perf_df["y_true"] - test_perf_df["y_pred"]
test_perf_df["abs_error"] = test_perf_df["error"].abs()
test_perf_df = test_perf_df.sort_values(
    ["material", "T_cfg"],
    ascending=[True, True]
).reset_index(drop=True)
test_perf_path = output_dir / "nn_test_predictions_cfg_plus_temperature.csv"
test_perf_df.to_csv(test_perf_path, index=False)
print("Saved test predictions:", test_perf_path)
# Save the final model checkpoint.
model_path = output_dir / "final_deepsets_cfg_plus_temperature.pt"
torch.save({
    "model_state_dict": final_model.state_dict(),
    "best_params": best_params,
    "feature_set": set_name,
    "use_temperature": use_temperature,
    "atom_input_dim": ATOM_FEATURE_DIM,
    "train_metrics": train_metrics,
    "test_metrics": test_metrics,
}, model_path)
print("Saved final model:", model_path)
# Out:
# Best params: {'atom_hidden': 64, 'latent_dim': 128, 'rho_hidden': 128, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 4}
# Mean CV test RMSE: 1.3556689889266327
# Train: {'r2': 0.9528705477714539, 'rmse': np.float64(1.6118118207485514), 'mae': 1.2483668327331543}
# Test : {'r2': 0.9603953957557678, 'rmse': np.float64(1.6811614201123708), 'mae': 1.3234517574310303}
# Saved test predictions: C:\Users\Admin\Downloads\cfg data\feature importance\nn_output\nn_test_predictions_cfg_plus_temperature.csv
# Saved final model: C:\Users\Admin\Downloads\cfg data\feature importance\nn_output\final_deepsets_cfg_plus_temperature.pt

# %%
# Save the final model without feature scaling
save_obj = {
    "model_state_dict": final_model.state_dict(),
    "best_params": best_params,
    "use_temperature": True,
    "elements": ELEMENTS,
    "max_atoms": MAX_ATOMS,
    "atom_feature_dim": 7,
}
torch.save(
    save_obj,
    output_dir / "final_deepsets_cfg_plus_temperature_with_latent.pt"
)
print("Saved:", output_dir / "final_deepsets_cfg_plus_temperature_with_latent.pt")
# Out:
# Saved: C:\Users\Admin\Downloads\cfg data\feature importance\nn_output\final_deepsets_cfg_plus_temperature_with_latent.pt

# %%
# Save metrics and test predictions for both input sets
final_summary_records = []
for use_temperature in [False, True]:
    set_name = "cfg_plus_temperature" if use_temperature else "cfg_only"
    # Select the best parameters from the completed CV search.
    best_params_row = (
        fold_metrics_df[fold_metrics_df["feature_set"] == set_name]
        .groupby("best_params", as_index=False)
        .agg(mean_test_rmse=("test_rmse", "mean"))
        .sort_values("mean_test_rmse", ascending=True)
        .iloc[0]
    )
    best_params = json.loads(best_params_row["best_params"])
    train_df, test_df = train_test_split(
        metadata_df,
        test_size=0.2,
        random_state=RANDOM_STATE
    )
    train_ds = CFGAtomDataset(train_df, use_temperature=use_temperature)
    test_ds = CFGAtomDataset(test_df, use_temperature=use_temperature)
    final_model, _ = train_one_model(
        train_ds,
        test_ds,
        best_params,
        use_temperature=use_temperature
    )
    y_train_true, y_train_pred = predict_dataset(
        final_model,
        train_ds,
        use_temperature=use_temperature
    )
    y_test_true, y_test_pred = predict_dataset(
        final_model,
        test_ds,
        use_temperature=use_temperature
    )
    train_metrics = calc_metrics(y_train_true, y_train_pred)
    test_metrics = calc_metrics(y_test_true, y_test_pred)
    final_summary_records.append({
        "feature_set": set_name,
        "model": "DeepSets",
        "best_params": json.dumps(best_params),
        "train_r2": train_metrics["r2"],
        "train_rmse": train_metrics["rmse"],
        "train_mae": train_metrics["mae"],
        "test_r2": test_metrics["r2"],
        "test_rmse": test_metrics["rmse"],
        "test_mae": test_metrics["mae"],
    })
    test_perf_df = test_df.copy().reset_index(drop=True)
    test_perf_df["feature_set"] = set_name
    test_perf_df["model"] = "DeepSets"
    test_perf_df["temperature"] = test_perf_df["T_cfg"]
    test_perf_df["logtau_true"] = y_test_true
    test_perf_df["logtau_pred"] = y_test_pred
    test_perf_df["error"] = test_perf_df["logtau_true"] - test_perf_df["logtau_pred"]
    test_perf_df["abs_error"] = test_perf_df["error"].abs()
    keep_cols = [
        "feature_set",
        "model",
        "material",
        "cfg_file_mapped",
        "cfg_path_mapped",
        "temperature",
        "logtau_true",
        "logtau_pred",
        "error",
        "abs_error",
    ]
    test_perf_df = test_perf_df[keep_cols].sort_values(
        ["material", "temperature"],
        ascending=[True, True]
    ).reset_index(drop=True)
    test_perf_path = output_dir / f"nn_test_performance_{set_name}.csv"
    test_perf_df.to_csv(test_perf_path, index=False)
    print("Saved:", test_perf_path)
final_summary_df = pd.DataFrame(final_summary_records)
final_summary_df = final_summary_df.sort_values(
    ["test_r2", "test_rmse", "test_mae"],
    ascending=[False, True, True]
).reset_index(drop=True)
summary_path = output_dir / "nn_final_metrics_summary.csv"
final_summary_df.to_csv(summary_path, index=False)
print("Saved:", summary_path)
final_summary_df
# Out:
# Saved: C:\Users\Admin\Downloads\cfg data\feature importance\nn_output\nn_test_performance_cfg_only.csv
# Saved: C:\Users\Admin\Downloads\cfg data\feature importance\nn_output\nn_test_performance_cfg_plus_temperature.csv
# Saved: C:\Users\Admin\Downloads\cfg data\feature importance\nn_output\nn_final_metrics_summary.csv
#             feature_set     model  \
# 0  cfg_plus_temperature  DeepSets
# 1              cfg_only  DeepSets
#
#                                          best_params  train_r2  train_rmse  \
# 0  {"atom_hidden": 64, "latent_dim": 128, "rho_hi...  0.965131    1.386407
# 1  {"atom_hidden": 64, "latent_dim": 128, "rho_hi...  0.917141    2.137162
#
#    train_mae   test_r2  test_rmse  test_mae
# 0   1.123872  0.963414   1.615831  1.224636
# 1   1.598628  0.924245   2.325102  1.530845

# %% [markdown]
# ## DeepSets input importance using Integrated Gradients
#
# DeepSets does not provide a tree-style `feature_importances_` attribute. Therefore, model-specific input importance is calculated using Integrated Gradients, without permuting the data or retraining the network. The reference input is defined by the mean atom-wise channels and mean temperature of the training set. Absolute attributions are averaged over the fixed test set and normalized to percentages. The element-type attribution describes dependence on the numerical element-ID encoding used by this model and should not be interpreted as a causal ordering of chemical elements.

# %%
# Integrated Gradients importance for the final DeepSets model
IG_STEPS = 32
IG_BATCH_SIZE = 2
if not final_model.use_temperature:
    raise ValueError("The final model must be the cfg_plus_temperature DeepSets model.")
ATOM_CHANNEL_NAMES = [
    "element_type",
    "fractional_x",
    "fractional_y",
    "fractional_z",
    "potential_energy",
    "force_magnitude",
    "centrosymmetry_parameter",
]
def calculate_training_reference(dataset):
    """Mean atom-wise channels and mean temperature over the training set."""
    loader = DataLoader(dataset, batch_size=8, shuffle=False)
    atom_sum = torch.zeros(7, dtype=torch.float64)
    atom_count = 0.0
    temperature_sum = 0.0
    sample_count = 0
    for batch in loader:
        atoms = batch["atoms"].double()
        mask = batch["mask"].double().unsqueeze(-1)
        atom_sum += (atoms * mask).sum(dim=(0, 1))
        atom_count += float(mask.sum())
        temperature_sum += float(batch["temperature"].double().sum())
        sample_count += int(batch["temperature"].shape[0])
    atom_reference = (atom_sum / max(atom_count, 1.0)).float()
    temperature_reference = float(temperature_sum / max(sample_count, 1))
    return atom_reference, temperature_reference
def integrated_gradients_importance(
    model,
    dataset,
    atom_reference,
    temperature_reference,
    steps=32,
    batch_size=2,
):
    """Calculate sample-level absolute Integrated Gradients attributions."""
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    model.eval()
    records = []
    sample_offset = 0
    atom_reference = atom_reference.to(device).view(1, 1, -1)
    temperature_reference_tensor = torch.tensor(
        [[temperature_reference]], dtype=torch.float32, device=device
    )
    for batch in loader:
        atoms = batch["atoms"].to(device)
        mask = batch["mask"].to(device)
        temperature = batch["temperature"].to(device)
        mask_expanded = mask.unsqueeze(-1)
        atom_baseline = atom_reference.expand_as(atoms) * mask_expanded
        temperature_baseline = temperature_reference_tensor.expand_as(temperature)
        atom_gradient_sum = torch.zeros_like(atoms)
        temperature_gradient_sum = torch.zeros_like(temperature)
        # Midpoint integration gives a stable approximation with a moderate number of steps.
        for step in range(steps):
            alpha = float(step + 0.5) / float(steps)
            atoms_step = (
                atom_baseline + alpha * (atoms - atom_baseline)
            ).detach().requires_grad_(True)
            temperature_step = (
                temperature_baseline
                + alpha * (temperature - temperature_baseline)
            ).detach().requires_grad_(True)
            prediction_step = model(atoms_step, mask, temperature_step)
            atom_gradient, temperature_gradient = torch.autograd.grad(
                outputs=prediction_step.sum(),
                inputs=(atoms_step, temperature_step),
                retain_graph=False,
                create_graph=False,
            )
            atom_gradient_sum += atom_gradient.detach()
            temperature_gradient_sum += temperature_gradient.detach()
        atom_ig = (
            (atoms - atom_baseline)
            * (atom_gradient_sum / float(steps))
            * mask_expanded
        )
        temperature_ig = (
            (temperature - temperature_baseline)
            * (temperature_gradient_sum / float(steps))
        )
        # Sum over atoms because each channel represents the whole configuration.
        atom_abs_attribution = atom_ig.abs().sum(dim=1)
        atom_signed_attribution = atom_ig.sum(dim=1)
        temperature_abs_attribution = temperature_ig.abs().squeeze(1)
        with torch.no_grad():
            prediction = model(atoms, mask, temperature).squeeze(1)
            baseline_prediction = model(
                atom_baseline, mask, temperature_baseline
            ).squeeze(1)
        output_difference = prediction - baseline_prediction
        attribution_sum = (
            atom_signed_attribution.sum(dim=1) + temperature_ig.squeeze(1)
        )
        completeness_error = output_difference - attribution_sum
        atom_abs_np = atom_abs_attribution.detach().cpu().numpy()
        temp_abs_np = temperature_abs_attribution.detach().cpu().numpy()
        pred_np = prediction.detach().cpu().numpy()
        baseline_pred_np = baseline_prediction.detach().cpu().numpy()
        output_diff_np = output_difference.detach().cpu().numpy()
        completeness_np = completeness_error.detach().cpu().numpy()
        for local_index in range(len(atom_abs_np)):
            row = dataset.df.iloc[sample_offset + local_index]
            record = {
                "sample_index": sample_offset + local_index,
                "material": row.get("material", "unknown"),
                "cfg_file": row.get("cfg_file_mapped", ""),
                "temperature": float(row["T_cfg"]),
                "prediction": float(pred_np[local_index]),
                "baseline_prediction": float(baseline_pred_np[local_index]),
                "output_difference": float(output_diff_np[local_index]),
                "completeness_error": float(completeness_np[local_index]),
                "temperature_abs_ig": float(temp_abs_np[local_index]),
            }
            for channel_index, channel_name in enumerate(ATOM_CHANNEL_NAMES):
                record[f"{channel_name}_abs_ig"] = float(
                    atom_abs_np[local_index, channel_index]
                )
            records.append(record)
        sample_offset += len(atom_abs_np)
    return pd.DataFrame(records)
atom_reference, temperature_reference = calculate_training_reference(train_ds)
deepsets_ig_per_sample_df = integrated_gradients_importance(
    final_model,
    test_ds,
    atom_reference,
    temperature_reference,
    steps=IG_STEPS,
    batch_size=IG_BATCH_SIZE,
)
# Channel-level importance: seven atom-wise channels plus temperature.
channel_records = []
for channel_name in ATOM_CHANNEL_NAMES + ["temperature"]:
    column = f"{channel_name}_abs_ig"
    values = deepsets_ig_per_sample_df[column].to_numpy(dtype=float)
    channel_records.append({
        "feature_set": "cfg_plus_temperature",
        "model": "DeepSets",
        "input_channel": channel_name,
        "mean_abs_integrated_gradient": values.mean(),
        "sd_abs_integrated_gradient": values.std(ddof=1),
    })
deepsets_ig_channel_df = pd.DataFrame(channel_records)
channel_total = deepsets_ig_channel_df["mean_abs_integrated_gradient"].sum()
deepsets_ig_channel_df["importance_percent"] = (
    100.0 * deepsets_ig_channel_df["mean_abs_integrated_gradient"]
    / channel_total
)
deepsets_ig_channel_df = deepsets_ig_channel_df.sort_values(
    "mean_abs_integrated_gradient", ascending=False
).reset_index(drop=True)
deepsets_ig_channel_df["importance_rank"] = np.arange(
    1, len(deepsets_ig_channel_df) + 1
)
# Group x, y, and z into one spatial-coordinate contribution for the manuscript figure.
group_columns = {
    "Element type": ["element_type_abs_ig"],
    "Spatial coordinates": [
        "fractional_x_abs_ig",
        "fractional_y_abs_ig",
        "fractional_z_abs_ig",
    ],
    "Potential energy": ["potential_energy_abs_ig"],
    "Force magnitude": ["force_magnitude_abs_ig"],
    "Centrosymmetry parameter": ["centrosymmetry_parameter_abs_ig"],
    "Temperature": ["temperature_abs_ig"],
}
group_records = []
for group_name, columns in group_columns.items():
    sample_values = deepsets_ig_per_sample_df[columns].sum(axis=1).to_numpy(float)
    group_records.append({
        "feature_set": "cfg_plus_temperature",
        "model": "DeepSets",
        "feature_group": group_name,
        "n_channels": len(columns),
        "mean_abs_integrated_gradient": sample_values.mean(),
        "sd_abs_integrated_gradient": sample_values.std(ddof=1),
    })
deepsets_ig_group_df = pd.DataFrame(group_records)
group_total = deepsets_ig_group_df["mean_abs_integrated_gradient"].sum()
deepsets_ig_group_df["importance_percent"] = (
    100.0 * deepsets_ig_group_df["mean_abs_integrated_gradient"]
    / group_total
)
deepsets_ig_group_df = deepsets_ig_group_df.sort_values(
    "mean_abs_integrated_gradient", ascending=False
).reset_index(drop=True)
deepsets_ig_group_df["importance_rank"] = np.arange(
    1, len(deepsets_ig_group_df) + 1
)
per_sample_path = output_dir / "deepsets_integrated_gradients_per_sample.csv"
channel_path = output_dir / "deepsets_integrated_gradients_channel_importance.csv"
group_path = output_dir / "deepsets_integrated_gradients_grouped_importance.csv"
deepsets_ig_per_sample_df.to_csv(per_sample_path, index=False)
deepsets_ig_channel_df.to_csv(channel_path, index=False)
deepsets_ig_group_df.to_csv(group_path, index=False)
print("Integrated Gradients steps:", IG_STEPS)
print("Atom reference:", atom_reference.numpy())
print("Temperature reference:", temperature_reference)
print(
    "Mean absolute completeness error:",
    deepsets_ig_per_sample_df["completeness_error"].abs().mean(),
)
print("Saved:", per_sample_path)
print("Saved:", channel_path)
print("Saved:", group_path)
deepsets_ig_group_df
# Out:
# Integrated Gradients steps: 32
# Atom reference: [ 1.69665     0.49950105  0.5005127   0.49972132 -5.469577    1.1000959
#   9.092151  ]
# Temperature reference: 785.2
# Mean absolute completeness error: 0.037345681052941546
# Saved: C:\Users\Admin\Downloads\cfg data\feature importance\nn_output\deepsets_integrated_gradients_per_sample.csv
# Saved: C:\Users\Admin\Downloads\cfg data\feature importance\nn_output\deepsets_integrated_gradients_channel_importance.csv
# Saved: C:\Users\Admin\Downloads\cfg data\feature importance\nn_output\deepsets_integrated_gradients_grouped_importance.csv
#             feature_set     model             feature_group  n_channels  \
# 0  cfg_plus_temperature  DeepSets          Potential energy           1
# 1  cfg_plus_temperature  DeepSets  Centrosymmetry parameter           1
# 2  cfg_plus_temperature  DeepSets       Spatial coordinates           3
# 3  cfg_plus_temperature  DeepSets               Temperature           1
# 4  cfg_plus_temperature  DeepSets              Element type           1
# 5  cfg_plus_temperature  DeepSets           Force magnitude           1
#
#    mean_abs_integrated_gradient  sd_abs_integrated_gradient  \
# 0                      8.523972                    4.626347
# 1                      6.292029                    3.445302
# 2                      5.580615                    2.930787
# 3                      4.814888                    5.079642
# 4                      3.324727                    1.682572
# 5                      3.102012                    1.517704
#
#    importance_percent  importance_rank
# 0           26.941991                1
# 1           19.887416                2
# 2           17.638826                3
# 3           15.218569                4
# 4           10.508570                5
# 5            9.804629                6
